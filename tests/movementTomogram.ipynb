# %%
import sys
sys.path = sys.path + ['/home/shuber/emmer']
from emmer.motionanalysis import load_motioncor_trajectories, load_cryosparc_trajectories, plot_trajectories_per_angle
from emmer.navigator import rotate_coordinates
import glob
import numpy as np

# %%
filenames = glob.glob('/home/shuber/emmer/tests/movement/*.txt')
pixelsize = 3.668
trajectories = load_motioncor_trajectories(filenames, pixelsize = pixelsize)
trajectories = rotate_coordinates(trajectories, 90+34.3)
angles = [float(i.split('_')[5]) for i in filenames]
plot_trajectories_per_angle(angles, trajectories, save='asd.png')
plot_trajectories_per_angle(angles, trajectories, sorted=True)
# Out:
# (<Figure size 525x1050 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f8885d69250>)

# %%
filenames = glob.glob('/home/shuber/scratch/27_20200414_SiNFilled_032020chips_20Sprot/tomos/tomo1/original/*.txt')
pixelsize = 3.668
trajectories = load_motioncor_trajectories(filenames, pixelsize = pixelsize)
trajectories = rotate_coordinates(trajectories, 90+34.3)
angles = [float(i.split('_')[9][:-4]) for i in filenames]
plot_trajectories_per_angle(angles, trajectories, save='/home/shuber/scratch/27_20200414_SiNFilled_032020chips_20Sprot/tomos/tomo1/movement.png')
plot_trajectories_per_angle(angles, trajectories, save='/home/shuber/scratch/27_20200414_SiNFilled_032020chips_20Sprot/tomos/tomo1/movement_sort.png', sorted=True)
# Out:
# (<Figure size 525x1050 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f88840f8610>)

# %%
filenames = glob.glob('/home/shuber/scratch/27_20200414_SiNFilled_032020chips_20Sprot/tomos/tomo2/original/*.txt')
pixelsize = 3.668
trajectories = load_motioncor_trajectories(filenames, pixelsize = pixelsize)
trajectories = rotate_coordinates(trajectories, 90+34.3)
angles = [float(i.split('_')[9][:-4]) for i in filenames]
fig,ax = plot_trajectories_per_angle(angles, trajectories, save='/home/shuber/scratch/27_20200414_SiNFilled_032020chips_20Sprot/tomos/tomo2/movement.png')
ax.set_xlim(-20,40); ax.set_ylim(-130,20); 
fig,ax = plot_trajectories_per_angle(angles, trajectories, save='/home/shuber/scratch/27_20200414_SiNFilled_032020chips_20Sprot/tomos/tomo2/movement_sort.png', sorted=True)
ax.set_xlim(-20,40); ax.set_ylim(-130,20);

# %%
filenames = glob.glob('/home/shuber/scratch/27_20200414_SiNFilled_032020chips_20Sprot/tomos/tomo3/original/*.txt')
pixelsize = 3.668
trajectories = load_motioncor_trajectories(filenames, pixelsize = pixelsize)
trajectories = rotate_coordinates(trajectories, 90+34.3)
angles = [float(i.split('_')[9][:-4]) for i in filenames]
fig,ax = plot_trajectories_per_angle(angles, trajectories, save='/home/shuber/scratch/27_20200414_SiNFilled_032020chips_20Sprot/tomos/tomo3/movement.png')
ax.set_xlim(-20,40); ax.set_ylim(-130,20); 
fig,ax = plot_trajectories_per_angle(angles, trajectories, save='/home/shuber/scratch/27_20200414_SiNFilled_032020chips_20Sprot/tomos/tomo3/movement_sort.png', sorted=True)
ax.set_xlim(-20,40); ax.set_ylim(-130,20);
